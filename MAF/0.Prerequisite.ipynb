# %% [markdown]
# # 🚀 시작하기 전 준비사항
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 10px; border-radius: 10px; color: white; margin-bottom: 10px;">
#
# ### ✨ 필수 요구사항
#
# 시작하기 전에 다음 항목들이 준비되어 있는지 확인하세요:
#
# </div>
#
# ### 📦 필수 소프트웨어
#
#
# 🐍 **Python 3.12**
#
# 이 워크숍은 `agent-framework==1.0.0` 기반으로 작성되었으며 Python 3.12에서 최적으로 실행됩니다.
# Python 3.10 이상도 동작 가능하나, 호환성을 위해 **Python 3.12 사용을 강력히 ✅ 권장**합니다.
# 📥 [Python 다운로드](https://www.python.org/downloads/)

# %% [markdown]
# ## 📋 설치 단계
#
# ### 1️⃣ 리포지토리 클론
#
# ```bash
# git clone https://github.com/taeyo-kim/MAF_Workshop.git
# cd MAF_Workshop
# ```
#
# ---
#
# ### 2️⃣ 가상환경 생성 및 활성화
#
# <div style="background: #fff4e6; border-left: 4px solid #ff9800; padding: 15px; border-radius: 8px; margin: 15px 0;">
#
# #### ⚠️ 중요
#
# **Python 3.12**로 가상 환경을 만드는 것이 `agent-framework==1.0.0`와의 최적 호환성을 위해 권장됩니다.
# </div>
#
# #### 🎨 Visual Studio Code에서 가상환경 생성
#
# <div style="background: #f5f5f5; padding: 15px; border-radius: 8px; border: 1px solid #e0e0e0;">
#
# **단계별 가이드:**
#
# 1. 📌 Visual Studio Code 터미널에서 `Ctrl + Shift + P` 입력
# 2. 🔍 명령 팔레트에서 `Python: Select Interpreter` 선택
# 3. ➕ `Create Virtual Environment` 선택
# 4. 🧿 `Venv Create a '.venv' virtual environment in the current workspace` 선택
# 5. 🐍 Python 3.12 인터프리터를 선택하여 `.venv` 환경 생성
#
# </div>

# %% [markdown]
# ---
#
# ### 3️⃣ Azure CLI 설치 및 로그인
#
# <div style="background: linear-gradient(80deg, #0078d4 0%, #50e6ff 100%); padding: 5px; border-radius: 5px; color: white; margin: 10px 0;">
#
# #### ☁️ Azure 인증 설정
#
# </div>
#
# **필수 단계:**
#
# 1. 🔧 [Azure CLI 설치](https://learn.microsoft.com/en-us/cli/azure/install-azure-cli)
# 2. 🔐 터미널에서 `az login` 실행
# 3. 🌐 브라우저에서 Azure 자격증명으로 로그인
#
# > 💡 **팁**: 로그인 후 터미널에서 구독 정보가 표시되면 성공입니다!

# %% [markdown]
# ---
#
# ### 4️⃣ pip Upgrade 및 Agent Framework 설치
#
# <div style="background: #e8f5e9; border-left: 4px solid #4caf50; padding: 15px; border-radius: 8px; margin: 15px 0;">
#
# #### 📦 패키지 설치
#
# pip를 최신 버전으로 업그레이드하고, 이번 워크샵에서 사용할 **Agent Framework**를 설치합니다.
# </div>

# %%
# 현재 Python 환경 설치 및 IPyKernel 설정
import sys
print("=" * 60)
print("🐍 Python 환경 정보")
print("=" * 60)
print(f"📍 실행 경로: {sys.executable}")
print(f"📊 버전: {sys.version}")
print("=" * 60)

# pip 업그레이드
# !pip install --upgrade pip

print("\n" + "=" * 60)
print("🔧 IPyKernel 설치 중...")
print("=" * 60)

# ipykernel 설치 (Jupyter 노트북 커널 지원)
# !pip install --upgrade ipykernel

# %% [markdown]
# 이어서 pywin32를 설치합니다.

# %%
# !pip install pywin32

# !.venv\Scripts\python.exe .venv\Scripts\pywin32_postinstall.py -install

# %% [markdown]
# 이제 VS Code의 상단에 있는 Restart를 눌러, **Kernel을 재시작**하세요.
#
# ![Restart Kernel](./images/ipy_restart.png)

# %% [markdown]
# 그리고, 이어서 **Microsoft Agent Framework**를 설치합니다.

# %%
print("\n" + "=" * 60)
print("📦 Agent Framework 설치 시작...")
print("=" * 60)

# agent-framework GA 버전 설치. 2026.04.03 릴리즈된 GA 버전
# !pip install agent-framework==1.0.0

print("\n✅ 설치 완료!")

# %% [markdown]
# **참고** 🗑️ Agent Framework 제거 (필요시)
#
# 기존에 설치된 agent-framework를 완전히 제거하려면 아래 셀을 실행하세요.

# %%
# 🗑️ Agent Framework 완전 제거
print("=" * 60)
print("🗑️  Agent Framework 제거 중...")
print("=" * 60)

# agent-framework 관련 모든 패키지 제거
# !pip uninstall -y agent-framework agent-framework-core agent-framework-azure-ai azure-ai-projects

# pip cache 정리
# !pip cache purge

print("\n✅ 제거 완료!")
print("💡 Kernel을 재시작한 후 새로 설치하세요")

# %% [markdown]
# #### 🔍 Agent Framework API 확인
#
# 설치된 agent-framework의 실제 클래스와 메서드를 확인합니다.

# %%
# 🔍 agent_framework 패키지의 실제 구조 확인
import agent_framework

print("=" * 70)
print("📦 AGENT FRAMEWORK 모듈 정보")
print("=" * 70)
print(f"🏷️  버전: {agent_framework.__version__ if hasattr(agent_framework, '__version__') else 'N/A'}")
print(f"\n📚 모듈 내용:")
modules = [x for x in dir(agent_framework) if not x.startswith('_')]
for i, module in enumerate(modules, 1):
    print(f"   {i}. {module}")

# %% [markdown]
# ---
#
# ### 5️⃣ Microsoft Foundry 프로젝트 생성 및 모델 배포
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 12px; color: white; margin: 15px 0;">
#
# #### 🎯 Azure AI Foundry 설정
#
# </div>
#
# **설정 단계:**
#
# | 단계 | 작업 | 링크 |
# |------|------|------|
# | 1️⃣ | 프로젝트 생성 | 📚 [프로젝트 만들기 가이드](https://learn.microsoft.com/ko-kr/azure/ai-foundry/how-to/create-projects?view=foundry-classic&tabs=foundry) |
# | 2️⃣ | 모델 배포 (GPT-4.1) | 📚 [모델 배포 가이드](https://learn.microsoft.com/en-us/azure/ai-foundry/foundry-models/how-to/deploy-foundry-models?view=foundry-classic) |
# | 3️⃣ | 권한 설정 | 📚 [역할 기반 액세스 제어](https://learn.microsoft.com/en-us/azure/ai-foundry/openai/how-to/role-based-access-control) |
# | 4️⃣ | 엔드포인트 확인 | 📋 배포된 모델의 엔드포인트 및 키 복사 |
#
# <div style="background: #e3f2fd; border-left: 4px solid #2196f3; padding: 15px; border-radius: 8px; margin: 15px 0;">
#
# #### 🔐 필수 권한
#
# 사용자에게 다음 역할 중 하나가 필요합니다:
# - ✅ **Cognitive Services OpenAI User**
# - ✅ **Cognitive Services OpenAI Contributor**
#
# </div>

# %% [markdown]
# ---
#
# ### 6️⃣ 환경 변수 설정 (.env 파일)
#
# <div style="background: #f3e5f5; border-left: 4px solid #9c27b0; padding: 5px 5px 5px 15px; border-radius: 8px; margin: 5px 0;">
#
# #### ⚙️ 환경 구성
#
# `.env` 파일을 생성하여 Azure 리소스 정보를 설정합니다.
#
# </div>
#
# **설정 방법:**
#
# 1. 📄 [.env.sample](../.env.sample) 파일을 복사하여 `.env`로 이름 변경
# 2. ✏️ 아래 템플릿을 참고하여 실제 값으로 수정
#
# ---
#
# #### 📋 환경 변수 템플릿
#
# ```bash
# # ──────────────────────────────────────────────────
# # 🔍 AI Search 설정
# # ──────────────────────────────────────────────────
# AZURE_SEARCH_ENDPOINT=https://<자신의_AI_Search_엔드포인트>
# AZURE_SEARCH_INDEX_NAME=hotels-sample-index
#
# # ──────────────────────────────────────────────────
# # 🎯 Foundry 프로젝트 설정
# # ──────────────────────────────────────────────────
# FOUNDRY_PROJECT_ENDPOINT=https://<자신의_프로젝트_엔드포인트>
# FOUNDRY_MODEL=gpt-4.1
#
# # ──────────────────────────────────────────────────
# # 📊 Aspire Dashboard 설정 (관찰성)
# # ──────────────────────────────────────────────────
# # 📚 참고: https://learn.microsoft.com/en-us/agent-framework/user-guide/observability?pivots=programming-language-python#setting-up-aspire-dashboard-with-docker
# ENABLE_INSTRUMENTATION=true
# OTEL_EXPORTER_OTLP_ENDPOINT=http://localhost:4317
#
# ```
#
# <div style="background: #fff3e0; border-left: 4px solid #ff9800; padding: 15px; border-radius: 8px; margin-top: 15px;">
#
# #### 💡 주의사항
#
# - `<자신의_AI_Search_엔드포인트>`, `<자신의_프로젝트_엔드포인트>` 부분을 실제 값으로 교체하세요
# - `.env` 파일은 Git에 커밋하지 마세요 (이미 `.gitignore`에 포함되어 있습니다)
#
# </div>
